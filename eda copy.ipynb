# %%
import pickle
import pandas as pd
import os
from datetime import date
import json

# %%
result_dir = 'result'
source_dir = 'source'

# %% [markdown]
# # False Results
# ## load data

# %%
# file_name = 'false_index_decoded.pkl' # included AVAILABLE_MOBILE_PLAN in the system prompt
# file_name = 'false_index_decoded_full2024-10-16.pkl' # removed AVAILABLE_MOBILE_PLAN in the system prompt the SKT provided
# file_name = 'false_index_decoded_2024-10-16.pkl' # removed AVAILABLE_MOBILE_PLAN, mobile plans and lineups from the system prompt
file_name = 'false_index_decoded_abridged_2024-10-23.pkl' # removed AVAILABLE_MOBILE_PLAN, mobile plans and lineups from the system prompt
file_path = os.path.join(result_dir, file_name)
with open(file_path, 'rb') as f:
    df:pd.DataFrame = pickle.load(f)
df.head(10)
# Out:
#                              user_query mismatch_type mismatch_args  \
# 390    0 청년 다이렉트 69 요금제 가입 가능해? 혜택도 궁금해        [name]          None
# 391  T끼리 55 요금제로 변경해도 괜찮을까? 특장점 있으면 말해줘        [name]          None
# 392       0플랜 히어로 상세 내용 궁금하네, 가입은 가능할까?        [name]          None
# 393   5GX 플래티넘(넷플릭스) 설명 듣고싶은데, 변경도 될라나?        [name]          None
# 394            나 5G 행복누리 슬림 요금제 지금 가입할래        [name]          None
# 395         나도 올인원 64 요금 상품으로다가 바로 신청할께        [name]          None
# 396                          마이투넘버 가입할래        [name]          None
# 397                        골든에이지15 신청할께        [name]          None
# 398                      변경가능해? PPS레귤러로        [name]          None
# 399                바꾸고 싶다 band 팅 3.0G으로        [name]          None
#
#                                        mismatch_result
# 390  SEARCH_MOBILE_PLAN != check_plan_availability....
# 391  SEARCH_MOBILE_PLAN != COMPARE_CHANGE_MY_MOBILE...
# 392  SEARCH_MOBILE_PLAN != check_plan_availability....
# 393  SEARCH_MOBILE_PLAN != check_plan_availability....
# 394  SEARCH_MOBILE_PLAN != check_plan_availability....
# 395  SEARCH_MOBILE_PLAN != check_plan_availability....
# 396  SEARCH_MOBILE_PLAN != check_plan_availability....
# 397  SEARCH_MOBILE_PLAN != check_plan_availability....
# 398  SEARCH_MOBILE_PLAN != check_plan_availability....
# 399  SEARCH_MOBILE_PLAN != COMPARE_CHANGE_MY_MOBILE...

# %% [markdown]
# ## function mismatch

# %%
df['mismatch_result'] = df['mismatch_result'].apply(lambda x: x.split('.')[0])
name_mismatch = df[df['mismatch_args'].isnull()].copy()
name_mismatch = name_mismatch.groupby('mismatch_result').agg({'mismatch_type':'count'})
print(name_mismatch.sum())
name_mismatch
# Out:
# mismatch_type    34
# dtype: int64
#                                                     mismatch_type
# mismatch_result
# SEARCH_MOBILE_PLAN != COMPARE_CHANGE_MY_MOBILE_...              2
# SEARCH_MOBILE_PLAN != check_plan_availability                  28
# SEARCH_MOBILE_PLAN != recommend_plans                           4

# %%
df[df['mismatch_args'].isnull()].drop('mismatch_args', axis=1)

with open(f'result/function_mismatch_details_{date.today()}.txt', 'w') as f:
    for i, group in df[df['mismatch_args'].isnull()].groupby('mismatch_result'):
        f.write(i + '\n')
        print(f'{i}')
        for row in group.itertuples():
            f_str = f'\t{row.user_query}'
            f.write(f_str + '\n')
            print(f_str)
# Out:
# SEARCH_MOBILE_PLAN != COMPARE_CHANGE_MY_MOBILE_PLAN
# 	T끼리 55 요금제로 변경해도 괜찮을까? 특장점 있으면 말해줘
# 	바꾸고 싶다 band 팅 3.0G으로
# SEARCH_MOBILE_PLAN != check_plan_availability
# 	0 청년 다이렉트 69 요금제 가입 가능해? 혜택도 궁금해
# 	0플랜 히어로 상세 내용 궁금하네, 가입은 가능할까?
# 	5GX 플래티넘(넷플릭스) 설명 듣고싶은데, 변경도 될라나?
# 	나 5G 행복누리 슬림 요금제 지금 가입할래
# 	나도 올인원 64 요금 상품으로다가 바로 신청할께
# 	마이투넘버 가입할래
# 	골든에이지15 신청할께
# 	변경가능해? PPS레귤러로
# 	내가 신청 할 수 있는 영상통화 한도없는 요금 플랜 안내해줘
# 	특정인이랑 제한없이 200분 이상 통화해도 되는 요금제 나도 가입할 수 있나?
# 	기본 제공 데이터가 용량 제한없는 요금 상품 알고싶어. 나 바꿔도 돼?
# 	나 데이터 100기가 이상 쓸 수 있는 요금제로 가입 가능할까?
# 	다른 폰에 연결해서 사용할건데,  내 스마트폰에서 모바일 데이터 같이 쓸 수 있는 요금제로 변경해줘
# 	매월 납부할 금액이 5만원 미만인 요금제 가입 돼?
# 	달마다 납부할 요금이 저렴한 요금제로 변경할 수 있어?
# 	데이터를 써도 써도 속도가 떨어지지 않는 요금 상품으로 바꿀래
# 	내가 변경 할 수 있는 영화 혜택 있는 모바일 요금제 알려줘
# 	나 넘버원 요금제 지금 가입할래
# 	나는 뉴 T끼리 맞춤형 요금제로 지금 바로 적용하고 싶어
# 	band YT 나 가입할래
# 	JOON인 내가 가입할 수 있는
# 	중학생 전용 요금제 가입돼?
# 	군인이 사용하는 요금제 가입가능해?
# 	대학생 전용 요금제 변경 가능해?
# 	청년 대상 요금제 등록할 수 있나
# 	온라인전용으로 가입할 수 있는 요금제 가입되나 봐줘
# 	가족이 결합할 수 있는 요금제 가입되나 확인해줘
# 	내가 선택할 수 있는 요금제 중에 청소년 전용 요금제 변경 가능해?
# SEARCH_MOBILE_PLAN != recommend_plans
# 	나 100GB 넘게 있는 요금 플랜으로 바꾸고 싶은데 추천해줄 수 있어?
# 	내게 기본 제공 데이터를 넉넉하게 퍼주는 요금 프로그램으로 가입할거거든, 뭐가 나을지 추천해줘
# 	이용자에게 데이터를 여유있게 주는 요금 플랜 바꿀거임. 어떤게 좋을지 알고싶어
# 	바꾸고 싶다 PPS 요금제

# %% [markdown]
# ## args mismatch

# %%
args_mismatch = df[~df['mismatch_args'].isnull()].copy()
args_mismatch['mismatch_type'] = args_mismatch['mismatch_type'].apply(lambda x: x[0])
args_mismatch['mismatch_arg1'] = args_mismatch['mismatch_args'].apply(lambda x: x[0] if x else 'empty response')
args_mismatch['mismatch_arg2'] = args_mismatch.apply(lambda row: row.mismatch_args[1] if len(row.mismatch_args) > 1 else row.mismatch_result, axis=1)
args_mismatch = args_mismatch.drop('mismatch_args', axis=1)
args_mismatch.head(10)
# Out:
#                                 user_query mismatch_type  \
# 433  나 기본 제공 데이터가 100GB를 초과하는 요금 플랜으로 변경할래     arguments
# 507                          가성비 요금제로 가입할래     arguments
#
#                mismatch_result mismatch_arg1 mismatch_arg2
# 433   100GB를 초과하는 != 100GB를 초과      keywords  includedData
# 507                가성비 != 경제적인      keywords  monthlyPrice

# %%
args_mismatch.index
# Out:
# Index(['433', '507'], dtype='object')

# %% [markdown]
# ### log probabilities of args mismatch

# %%
with open(f'{result_dir}/logprobs_gpt4o_v202408.json', 'r') as f:
    logprobs = json.load(f)

logprob_df = pd.DataFrame.from_dict({id:[log_prob['avg_prob']] for id, log_prob in logprobs.items()}, orient='index', columns=['prob'])

# filter out mismatched arguments only
logprob_df = logprob_df[~logprob_df.index.isin(args_mismatch.index)]
print(logprob_df.info())
print(logprob_df.head(10))
print(logprob_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 390 to 597
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   prob    36 non-null     float64
# dtypes: float64(1)
# memory usage: 576.0+ bytes
# None
#          prob
# 390  0.999932
# 391  0.999990
# 392  0.996026
# 393  0.993110
# 394  0.999934
# 395  0.999961
# 396  0.969663
# 397  0.999384
# 398  0.986509
# 399  0.999874
#             prob
# count  36.000000
# mean    0.986368
# std     0.018913
# min     0.930674
# 25%     0.971536
# 50%     0.998564
# 75%     0.999888
# max     0.999990

# %% [markdown]
# ### log probability charts

# %%
import matplotlib.pyplot as plt

def plot_histogram(logprob_df):
    plt.figure(figsize=(10, 6))
    plt.hist(logprob_df['prob'], bins=30, color='lightgreen', edgecolor='black')
    plt.title('Distribution of Average Probabilities')
    plt.xlabel('Average Probability')
    plt.ylabel('Frequency')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# Call the function
plot_histogram(logprob_df)

# %% [markdown]
# ## mismatch under 0.95

# %%
# function mismatch
name_mismatch_under_95 = pd.merge(df, logprob_df.query('prob < 0.95'), how='inner', left_index=True, right_index=True)
name_mismatch_under_95
# Out:
#                                    user_query mismatch_type mismatch_args  \
# 435  나 100GB 넘게 있는 요금 플랜으로 바꾸고 싶은데 추천해줄 수 있어?        [name]          None
# 588                         JOON인 내가 가입할 수 있는        [name]          None
#
#                                    mismatch_result      prob
# 435          SEARCH_MOBILE_PLAN != recommend_plans  0.938809
# 588  SEARCH_MOBILE_PLAN != check_plan_availability  0.930674

# %%
# argument mismatch
arg_mismatch_under_95 = pd.merge(args_mismatch, logprob_df.query('prob < 0.95'), how='inner', left_index=True, right_index=True)
arg_mismatch_under_95
# Out:
# Empty DataFrame
# Columns: [user_query, mismatch_type, mismatch_result, mismatch_arg1, mismatch_arg2, prob]
# Index: []

# %% [markdown]
# ### keyword detection from user query
# - This result is not inaccurate response, but it is rather for your reference in detail

# %%
keywords_mismatch = args_mismatch.query("not mismatch_arg2.str.contains('dict')").copy()
print('total: ', len(keywords_mismatch))
keywords_mismatch.query("not mismatch_arg2.str.contains('dict')").groupby(['mismatch_arg1','mismatch_arg2']).agg({'user_query':'count'}).sort_values('user_query', ascending=False)
# Out:
# total:  46
#                                                    user_query
# mismatch_arg1 mismatch_arg2
# keywords      includedVoiceCall                             5
#               monthlyPrice                                  5
#               onboardingChannel                             5
#               optionData                                    5
#               includedDataForSharingAndTethering            4
#               includedVoiceCallTospecifiedNumbers           4
#               maximumAmountForSharing                       4
#               benefit                                       3
#               includedVideoOrValueAddedCall                 3
#               onboardingDeviceAlias                         3
#               availableAmountForDataOptionRefill            2
#               includedText                                  2
#               onboardingDevice                              1

# %%
keywords_mismatch[['user_query', 'mismatch_result','mismatch_arg2']]
# Out:
#                                             user_query  \
# 194         전화 50분으론 택도 없네.나 음성 75분 이상 제공되는 요금제  찾고 싶어
# 205                      영상통화 공짜로 300분 정도 주는 요금 상품 뭐야?
# 207                영상통화 모자라지 않게 제공되는 요금제 이용하고 싶은데 안내해줘
# 211                  내가 어머니랑 음성 전화 무료로 할 수 있는 요금제 가르쳐줘
# 213                어머니랑 제한없이 200분 이상 통화해도 되는 요금제 뭐 있어?
# 237                  테더링 용량을 제한 없이 써도 문제 없는 요금 상품 제공해줘
# 239     다른 핸드폰이랑 페어링해서 모바일 데이터 이용하려는데 제공량 큰 요금 상품 가르쳐줘
# 243                  데이터 공유가 제한없이 가능한 요금 상품 찾고 있는데 말해줘
# 249                                        데이터 쉐어 충분한거
# 255                               주말용 데이터가 나오는 요금제 말해줘
# 263  지금 당장 리필쿠폰 기준량 20기가 정도의 휴대폰 요금제는 뭐가 좋을지 추천 부탁해...
# 275      모바일 데이터 나눠주기가 허용되는 용량이 500mb 정도 되는 요금 상품 소개해줘
# 276          용량이 어느정도 있는 모바일 데이터를 나눠 줄 수 있는 요금 플랜 가르쳐줘
# 287                기본 제공 무료 문자가 모자라지 않게 있는 요금 플랜 어떤거야?
# 291                               정액요금이 10만원 쯤인 요금제 찾기
# 295                                     9만원 정도인 요금제 검색
# 324                     요금 서비스중에 결합 혜택이 있는걸 쓰고 싶은데 알려줘
# 344                                  매장에서 무슨 요금제 가능하지?
# 346                            오프라인으로 요금제 어떤 거 할 수 있지?
# 348                               휴대폰 판매점에서 할 수 있는 요금제
# 400                       나 음성통화 없는 요금제 가입하고 싶은데 알려줄래?
# 403                       나 음성통화 제한 없이 할 수 있는 요금 플랜 쓸래
# 404                           음성 75분 이상 제공되는 요금제 가입할거야
# 405              전화통화 450분 보다 많이 쓸 수 있는 모바일 플랜으로 변경할거야
# 412                      내가 쓸 수  있는 영상통화 무제한 요금 상품 말해줘
# 420               부모님이랑 통화 무제한으로 할 수 있는 요금제 나도 가입하고 싶어
# 421      내가 등록한 사람 전화 통화 한도 없이 해도 되는 요금제 나도 변경되는 거 알려줘
# 465          내꺼 변경할건데,  일요일에 데이터 계속 쓸 수 있는 모바일 플랜 뭐있어?
# 466                    내가 사용할건데,  심야에 데이터 할인하는 요금제 말해봐
# 468          내꺼 변경할 건데,  매일 3시간 무제한 데이터 옵션이 있는 요금제 찾아줘
# 469     내가 쓸 수 있는 걸로 매일 몇시간 무제한 데이터 쓸 수 있는 모바일 상품 안내해줘
# 477      지금 바로 데이터 쿠폰이 조금 있는 적용된 요금 플랜 바꾸고 싶은데, 리스트업해줘
# 485     내가 바꿀 수 있는 요금 상품 중 데이터 나눔을 1기가 초과 해도 되는 거 안내해줘
# 488                 요금 플랜 중에서 데이터 넉넉하게 나눠주기 가능한 걸로 바꿀래
# 497              문자 기본제공 50건 정도 되는 모바일 요금제 쓰고 싶은데 안내해줘
# 502                          월정액 별로 안비싼 걸로 요금제 가입하고 싶어
# 504                           5만원 미만인 요금제 할 수 있는 거 알려줘
# 505                                  10만원 쯤인 요금제로 가입할래
# 535                        내가 가입 가능한 선물 혜택 있는 요금제 나열해봐
# 537                             데이터 혜택 들어있는 요금 상품 쓰고싶어
# 558                           나는 티월드에서 어떤 요금제 가입 가능한 거
# 559                  나는 오프라인 매장에서 어느 요금제 가입 할 수 있는 거야?
# 579                나 스마트폰 아닌 폰 용 모바일 플랜 뭐 쓸 수 있는지 가르쳐줘
# 581              지금 갤럭시에이스 사용 하는데 내가 이용 가능한 요금 서비스 뭐야?
# 587      갤럭시 탭 A7IPHONE SE 2022 쓰고 있는데 요금 상품 이용할 수 있는거
# 589                                  LG폴더2인 내가 가입 가능한거
#
#                                mismatch_result  \
# 194                              75분 != 75분 이상
# 205                            300분 정도 != 300분
# 207                         모자르지 않게 != 모자라지 않게
# 211                                  무료로 != 무료
# 213                    200분 이상 != 제한없이 200분 이상
# 237                                무한 != 제한 없이
# 239                                 큰 != 제공량 큰
# 243                                제한없이 != 무제한
# 249                                  충분 != 충분한
# 255                                     != 주말용
# 263                            30기가 정도 != 20기가
# 275                      2GB 보다 많은 != 500mb 정도
# 276                            어느정도 있는 != 어느정도
# 287                         모자르지 않게 != 모자라지 않게
# 291                             10만원 쯤 != 10만원
# 295                              9만원 정도 != 9만원
# 324                                결합 != 결합 혜택
# 344                                  매장 != 판매점
# 346                                오프라인 != 판매점
# 348                             휴대폰 판매점 != 판매점
# 400                                      != 없음
# 403                               제한 없이 != 무제한
# 404                              75분 != 75분 이상
# 405                    450분 보다 더 != 450분 보다 많이
# 412                                제한없는 != 무제한
# 420                                     != 무제한
# 421                                   != 한도 없이
# 465                                     != 일요일
# 466                               != 심야 데이터 할인
# 468                              != 매일 3시간 무제한
# 469                              != 매일 몇시간 무제한
# 477                                조금 있는 != 조금
# 485                           2GB 넘게 != 1기가 초과
# 488                                넉넉하게 != 넉넉한
# 497                              50건 정도 != 50건
# 502                              안비싼 != 별로 안비싼
# 504                          5만원 미만인 != 5만원 미만
# 505                            10만원 쯤인 != 10만원
# 535                                선물 != 선물 혜택
# 537                              데이터 != 데이터 혜택
# 558                                 티월드 != T월드
# 559                             오프라인 매장 != 판매점
# 579                   스마트폰 아닌 폰 != 스마트 기능 없는 폰
# 581                          갤럭시에이스 != 갤럭시 에이스
# 587   갤럭시 탭 A7IPHONE SE 2022 != IPHONE SE 2022
# 589                            LG폴더2 != LG 폴더2
#
#                            mismatch_arg2
# 194                    includedVoiceCall
# 205        includedVideoOrValueAddedCall
# 207        includedVideoOrValueAddedCall
# 211  includedVoiceCallTospecifiedNumbers
# 213  includedVoiceCallTospecifiedNumbers
# 237   includedDataForSharingAndTethering
# 239   includedDataForSharingAndTethering
# 243   includedDataForSharingAndTethering
# 249   includedDataForSharingAndTethering
# 255                           optionData
# 263   availableAmountForDataOptionRefill
# 275              maximumAmountForSharing
# 276              maximumAmountForSharing
# 287                         includedText
# 291                         monthlyPrice
# 295                         monthlyPrice
# 324                              benefit
# 344                    onboardingChannel
# 346                    onboardingChannel
# 348                    onboardingChannel
# 400                    includedVoiceCall
# 403                    includedVoiceCall
# 404                    includedVoiceCall
# 405                    includedVoiceCall
# 412        includedVideoOrValueAddedCall
# 420  includedVoiceCallTospecifiedNumbers
# 421  includedVoiceCallTospecifiedNumbers
# 465                           optionData
# 466                           optionData
# 468                           optionData
# 469                           optionData
# 477   availableAmountForDataOptionRefill
# 485              maximumAmountForSharing
# 488              maximumAmountForSharing
# 497                         includedText
# 502                         monthlyPrice
# 504                         monthlyPrice
# 505                         monthlyPrice
# 535                              benefit
# 537                              benefit
# 558                    onboardingChannel
# 559                    onboardingChannel
# 579                     onboardingDevice
# 581                onboardingDeviceAlias
# 587                onboardingDeviceAlias
# 589                onboardingDeviceAlias

# %% [markdown]
# ### keywords mismatch

# %%
import re

args_mismatch_dict = args_mismatch.query("mismatch_result.str.contains('dict', case=False)").copy()
args_mismatch_dict['mismatch_arg2'] = args_mismatch_dict.apply(
    lambda row: re.sub(r'dict_keys|\(|\)', '', row.mismatch_arg2) if pd.notnull(row.mismatch_arg2) else row.mismatch_arg2, 
    axis=1
)
# print(args_mismatch_dict.columns)
print('total:', args_mismatch_dict['mismatch_result'].count())

args_mismatch_keys = args_mismatch_dict.groupby(['mismatch_type','mismatch_arg2']).agg({'user_query':'count'})
args_mismatch_keys
# Out:
# total: 58
#                                                                   user_query
# mismatch_type mismatch_arg2
# arguments     [benefit] != [availableAmountForDataOptionRefill]            1
#               [includedDataForSharingAndTethering] != [includ...           1
#               [includedDataForSharingAndTethering] != [maximu...          11
#               [includedDataForSharingAndTethering] != [onboar...           1
#               [includedData] != [maximumAmountForSharing]                  1
#               [lineup] != [includedVoiceCall]                              1
#               [lineup] != [productName]                                    9
#               [maximumAmountForSharing] != [includedData]                  2
#               [onboardingDevice] != [specialCustomerOnboard]               1
#               [onboardingTypeEligibility] != [onboardingChann...           2
#               [onboardingTypeEligibility] != [onboardingTypeE...           6
#               [optionData] != [includedData, optionData]                   1
#               [optionData] != [includedData]                               1
#               [plan] != [keywords]                                        10
#               [plans] != [keywords]                                       10

# %%
args_mismatch_dict = args_mismatch_dict[['user_query','mismatch_arg2', 'mismatch_type']]

# display
with open(f'result/argments_keyword_mismatch_detail_{date.today()}.txt', 'w') as f:
    for i, group in args_mismatch_dict.groupby(['mismatch_arg2']):
        t_str = f"{group['mismatch_arg2'].unique()[0]}"
        f.write(t_str + '\n')
        print(t_str)
        for row in group.itertuples():
            t_str = f'\t{row.user_query}'
            f.write(t_str + '\n')
            print(t_str)
# Out:
#  [benefit] != [availableAmountForDataOptionRefill]
# 	리필 혜택 요금플랜 가입할게
#  [includedDataForSharingAndTethering] != [includedData]
# 	데이터 많이 줄 수 있는거 가입하려고 해
#  [includedDataForSharingAndTethering] != [maximumAmountForSharing]
# 	가족끼리 데이터 공유할 수 있는 요금제  찾고 있는데 알려줘
# 	가족끼리 데이터 주고 받을 수 있는 요금 상품 보고 있는데 뭐가있어?
# 	데이터 쉐어를 제한없이 할 수 있는 요금 상품이 뭐야?
# 	많이 데이터 공유 가능한게 뭐가 있어?
# 	노트북에 핫스팟해서 데이터 쓸거야.  내 폰에서 데이터 줄 수 있는 요금제 가입할래
# 	내가 가입할 수 있는 데이터 공유할 수 있는 요금제 알려줘
# 	내가 사용할 수 있는 데이터 줄 수 있는 요금 서비스 어떤거야?
# 	60기가 보다 많이 데이터 줄 수 있는 요금 플랜 쓰고 싶어
# 	나 데이터 충분하게 공유할 수 있는 요금제  가입하고 싶은데 뭐가 있어?
# 	나 데이터 넉넉하게 공유 되는 모바일 요금제 가입할건데 안내해줘
# 	데이터 꽤 보낼 수 있는거 사용하고 싶어
#  [includedDataForSharingAndTethering] != [onboardingDevice, maximumAmountForSharing]
# 	태블릿에 연결해서 쓸거야. 내 폰에서 데이터 제공 할 수 있는 요금제 알려줘
#  [includedData] != [maximumAmountForSharing]
# 	나에게 기본 데이터 부족함없이 나눠주는 모바일 요금제는 어떤건지 정리 좀 해줄래?
#  [lineup] != [includedVoiceCall]
# 	나 지금 무료음성 요금제 가입할래
#  [lineup] != [productName]
# 	나에게 5GX플랜 요금제에 대해 정보를 자세히 알려줘
# 	요금제 바꾸고 싶은데나한테 뉴실버 요금제의 특징을 자세하게 설명 좀 해줘
# 	0청년 요금제에 대한 특징을 나 알고싶어
# 	요금제 중 LTE 다이렉트플랜 특징을 알려줘 나한테
# 	0히어로 특징에 대해 상세히 말해줘
# 	다이렉트플랜을 나한테 상세하게 설명해줄래?
# 	0청년 요금제로 적용 괜찮을까? 설명 좀 듣고싶어
# 	T끼리 요금제로 변경하고 싶은데, 특장점 있으면 말해줘
# 	T시그니처 요금제로 바꾸고 싶어. 부가설명 좀 해주셈
#  [maximumAmountForSharing] != [includedData]
# 	용량이 충분한 데이터를 주는 게 문제없는 요금 플랜 안내해줘
# 	나 이용 가능한 요금제 중 데이터를 부족하지 않게 줘도 문제 없는 거 보여줘
#  [onboardingDevice] != [specialCustomerOnboard]
# 	나에게 아동용 휴대폰 전용 요금제 제공해줘
#  [onboardingTypeEligibility] != [onboardingChannel, onboardingTypeEligibility]
# 	티다샵에서 가입할 수 있는 유심 등록되는 요금 상품 바로 확인 좀~ 바꿔보고 싶어.
# 	T-Direct샵에서 가입 가능한 USIM 전용 요금 플랜 지금 당장 조회가능? 써볼라고
#  [onboardingTypeEligibility] != [onboardingTypeEligibility, onboardingChannel]
# 	티다이렉트샵에서 가입 가능한 유심 전용 요금제 알려줘
# 	티다샵에서 가입할 수 있는 유심 등록되는 요금제 확인 좀
# 	T Direct에서 가입되는 유심 개통 요금제 리스트업해봐
# 	T-Direct샵에서 가입 가능한 USIM 전용 요금제 있을까?
# 	티다이렉트샵에서 가입 가능한 유심 전용 요금제 지금 알려줘. 변경하고 싶어.
# 	티다이렉트샵에서 가입 가능한 유심 전용 요금제 알려줘. 변경하고 싶어.
#  [optionData] != [includedData, optionData]
# 	내가 가입거야.  주말에 데이터 무제한인 요금제 찾아줘
#  [optionData] != [includedData]
# 	주말에 데이터 무제한인 요금제 알려줘
#  [plan] != [keywords]
# 	내가 지금 온가족 행복플랜85 요금제인데 온가족 행복플랜78으로 변경하면 뭐가 달라져?
# 	내가 현재 온가족 행복플랜48 요금 플랜인데 온가족 행복플랜38으로 전환하면 무슨 차이야?
# 	지금 내가 안심음성500 요금제인데 안심음성350으로 변경하면 뭐가 달라져?
# 	뉴 T끼리 맞춤형(150분+3GB)으로 변경하면 지금 나의 뉴 T끼리 맞춤형(150분+1.5GB) 요금제에서 뭐가 달라지는거?
# 	LTE 복지210+에서 LTE 복지150+으로 변경하면 달라지는거
# 	다다익선800요금제으로 다다익선400요금제에서 변경하면 바뀌는거
# 	내가 T 케어(한도형) 요금제로 바꾸면 어떤게 달라져?
# 	내가 PPS스마트폰 플러스 요금플랜으로 이동하면 뭐가 좋아져?
# 	내가 골든에이지15으로 바꾸면 어떻게 달라져?
# 	달라지는게 뭐야 내가 골든에이지 온가족36으로 바꾸면?
#  [plans] != [keywords]
# 	바꾸고 싶어서 그러는데, 다이렉트5G 69이랑 다이렉트5G 62 요금제 차이점이 뭐야?
# 	다이렉트5G 42이랑 다이렉트5G 38 요금제 분석 해줄래?
# 	뉴실버요금제와 T끼리 어르신은 다른게 뭐지?
# 	어떤게 달라 다이렉트LTE 48랑 다이렉트LTE 30
# 	band 데이터 퍼펙트와 요금제와 band 데이터 퍼펙트S 요금제는 어떻게 다른가요?
# 	band 데이터 1.2G와 요금 체계와 band 데이터 2.2G 요금 체계를 구별 해줄래?
# 	0플랜 히어로랑 0플랜 슈퍼히어로 요금제의 세부 사항 어떻게 다른거지?
# 	요금제중 T플랜 세이브+다이렉트플랜과 T플랜 안심2.5G+다이렉트플랜의 차이는 어떤걸까?
# 	요금제 팅프리존24요금과 팅프리존19요금의 차이는?
# 	팅500요금제과 팅100요금제의 차이점은?

# %% [markdown]
# #### shared arguments

# %%
import json

shared_args_file_name = 'shared_arguments.json'
shared_args_file_path = os.path.join(source_dir, shared_args_file_name)
with open(shared_args_file_path, 'r') as f:
    shared_args = json.load(f)

key_desc = shared_args['keywords']['properties']
key_desc['plan']= shared_args['plan']
key_desc['plans'] = shared_args['plans']
key_desc
# Out:
# {'productName': {'default': 'null',
#   'description': 'name of mobile plan',
#   'title': 'Productname',
#   'type': 'string'},
#  'includedVoiceCall': {'default': 'null',
#   'description': 'The amount of voice calls provided by the plan',
#   'title': 'Includedvoicecall',
#   'type': 'string'},
#  'includedVideoOrValueAddedCall': {'default': 'null',
#   'description': 'The amount of video calls(영상통화) or added calls(부가통화) provided by the plan',
#   'title': 'Includedvideoorvalueaddedcall',
#   'type': 'string'},
#  'includedVoiceCallTospecifiedNumbers': {'default': 'null',
#   'description': 'The amount of voice calls to specified numbers (지정통화) provided by the plan',
#   'title': 'Includedvoicecalltospecifiednumbers',
#   'type': 'string'},
#  'includedData': {'default': 'null',
#   'description': 'The amount of data. Generally GB units are used.',
#   'title': 'Includeddata',
#   'type': 'string'},
#  'includedDataForSharingAndTethering': {'default': 'null',
#   'description': 'The amount of sharing and tethering data.',
#   'title': 'Includeddataforsharingandtethering',
#   'type': 'string'},
#  'optionData': {'default': 'null',
#   'description': 'data provided in addition to the basic data provided',
#   'title': 'Optiondata',
#   'type': 'string'},
#  'availableAmountForDataOptionRefill': {'default': 'null',
#   'description': 'amount of data refill',
#   'title': 'Availableamountfordataoptionrefill',
#   'type': 'string'},
#  'maximumAmountForSharing': {'default': 'null',
#   'description': 'The maximum amount of data that can be shared with others',
#   'title': 'Maximumamountforsharing',
#   'type': 'string'},
#  'includedText': {'default': 'null',
#   'description': 'amount of SMS',
#   'title': 'Includedtext',
#   'type': 'string'},
#  'monthlyPrice': {'default': 'null',
#   'description': 'amount of monthly price. KRW(원) units are used.',
#   'title': 'Monthlyprice',
#   'type': 'string'},
#  'generation': {'default': 'null',
#   'description': 'Available mobile networks (5G, LTE, etc.)',
#   'title': 'Generation',
#   'type': 'string'},
#  'dataQoS': {'default': 'null',
#   'description': 'Speed control when you can continue to use data without additional charges after your default data limit has been used up',
#   'title': 'Dataqos',
#   'type': 'string'},
#  'benefit': {'default': 'null',
#   'description': 'benefits of the mobile plan',
#   'title': 'Benefit',
#   'type': 'string'},
#  'lineup': {'default': 'null',
#   'description': 'The name of the parent group to which the mobile plan belongs',
#   'title': 'Lineup',
#   'type': 'string'},
#  'onboardingChannel': {'default': 'null',
#   'description': 'Channel to subscribe to the product',
#   'title': 'Onboardingchannel',
#   'type': 'string'},
#  'onboardingTypeEligibility': {'default': 'null',
#   'description': 'Available subscription types',
#   'title': 'Onboardingtypeeligibility',
#   'type': 'string'},
#  'onboardingDevice': {'default': 'null',
#   'description': 'device for subscribing to the product',
#   'title': 'Onboardingdevice',
#   'type': 'string'},
#  'onboardingDeviceAlias': {'default': 'null',
#   'description': 'alias of device for subscribing to the product',
#   'title': 'Onboardingdevicealias',
#   'type': 'string'},
#  'specialCustomerOnboard': {'default': 'null',
#   'description': 'Customer type segment (military, college student, etc.)',
#   'title': 'Specialcustomeronboard',
#   'type': 'string'},
#  'plan': {'description': 'SKTelecom mobile plan you want to change.',
#   'type': 'string'},
#  'plans': {'description': 'List of SKTelecom mobile plans.',
#   'type': 'array',
#   'items': {'type': 'string'}}}

# %%
arg_keys = args_mismatch_keys.reset_index()

with open(f'result/conflicted_argument_descriptions.txt', 'w') as f:
    for row in arg_keys.itertuples():
        true_key, llm_key = row.mismatch_arg2.split('!=')
        try:
            true_key_desc = key_desc[true_key.strip().strip('[]')]['description']
        except (KeyError, ValueError) as e:
            raise Exception(f"Error with key : {true_key.strip()}(where there are {len(true_key.strip())} chars)")

        t_str = f"{true_key} -> {llm_key}\n\t{true_key_desc}"
        f.write(t_str + '\n')
        print(t_str)

        llm_key = llm_key.strip().strip('[]')
        llm_key = llm_key.split(', ') if ',' in llm_key else [llm_key.strip()]

        for key in llm_key:
            if key.strip() != true_key.strip().strip('[]'):
                try:
                    llm_key_desc = key_desc[key.strip()]['description']
                except:
                    t_str = f"\tERROR: '{key.strip()}' not found in the shared arguments"
                    f.write(t_str + '\n')
                    print(t_str)
                else:
                    t_str = f"\t{llm_key_desc}"
                    f.write(t_str + '\n')
                    print(t_str)
# Out:
#  [benefit]  ->  [availableAmountForDataOptionRefill]
# 	benefits of the mobile plan
# 	amount of data refill
#  [includedDataForSharingAndTethering]  ->  [includedData]
# 	The amount of sharing and tethering data.
# 	The amount of data. Generally GB units are used.
#  [includedDataForSharingAndTethering]  ->  [maximumAmountForSharing]
# 	The amount of sharing and tethering data.
# 	The maximum amount of data that can be shared with others
#  [includedDataForSharingAndTethering]  ->  [onboardingDevice, maximumAmountForSharing]
# 	The amount of sharing and tethering data.
# 	device for subscribing to the product
# 	The maximum amount of data that can be shared with others
#  [includedData]  ->  [maximumAmountForSharing]
# 	The amount of data. Generally GB units are used.
# 	The maximum amount of data that can be shared with others
#  [lineup]  ->  [includedVoiceCall]
# 	The name of the parent group to which the mobile plan belongs
# 	The amount of voice calls provided by the plan
#  [lineup]  ->  [productName]
# 	The name of the parent group to which the mobile plan belongs
# 	name of mobile plan
#  [maximumAmountForSharing]  ->  [includedData]
# 	The maximum amount of data that can be shared with others
# 	The amount of data. Generally GB units are used.
#  [onboardingDevice]  ->  [specialCustomerOnboard]
# 	device for subscribing to the product
# 	Customer type segment (military, college student, etc.)
#  [onboardingTypeEligibility]  ->  [onboardingChannel, onboardingTypeEligibility]
# 	Available subscription types
# 	Channel to subscribe to the product
#  [onboardingTypeEligibility]  ->  [onboardingTypeEligibility, onboardingChannel]
# 	Available subscription types
# 	Channel to subscribe to the product
#  [optionData]  ->  [includedData, optionData]
# 	data provided in addition to the basic data provided
# 	The amount of data. Generally GB units are used.
#  [optionData]  ->  [includedData]
# 	data provided in addition to the basic data provided
# 	The amount of data. Generally GB units are used.
#  [plan]  ->  [keywords]
# 	SKTelecom mobile plan you want to change.
# 	ERROR: 'keywords' not found in the shared arguments
#  [plans]  ->  [keywords]
# 	List of SKTelecom mobile plans.
# 	ERROR: 'keywords' not found in the shared arguments

# %% [markdown]
# # Response time

# %%
result_file_name = 'results_full_20241017_1615.pkl'
result_file_path = os.path.join(result_dir, result_file_name)

with open(result_file_path, 'rb') as f:
    time_lapse_data = pickle.load(f)['time_lapse']

time_lapse_df = pd.DataFrame({'row_num':time_lapse_data.keys(), 'time_lapse':time_lapse_data.values()})
time_lapse_df
# Out:
#     row_num  time_lapse
# 0         0    1.677031
# 1         1    1.717854
# 2         2    3.273967
# 3         3    1.663740
# 4         4    1.937209
# ..      ...         ...
# 595     595    4.216356
# 596     596    4.044506
# 597     597    2.918001
# 598     598    8.031794
# 599     599    7.824969
#
# [600 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a scatter plot
numbers = time_lapse_df.query('time_lapse < 20')['time_lapse'].values
print(f'total N: {len(numbers)}\nmean: {numbers.mean():.2f}, median: {np.median(numbers):.2f}\nmin: {numbers.min():.2f}, max: {numbers.max():.2f}')
plt.hist(numbers, bins=15, edgecolor='black')

# Add labels and title
plt.xlabel('')
plt.ylabel('Value')
plt.title('Time Lapse')

# Show the plot
plt.show()
# Out:
# total N: 588
# mean: 3.53, median: 2.42
# min: 1.45, max: 17.98
